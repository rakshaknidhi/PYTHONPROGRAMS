# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshaknidhi/PYTHONPROGRAMS/blob/master/Tupple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t=tuple("Hello")
print(t)
# Out:
# ('H', 'e', 'l', 'l', 'o')

# %%
z#crete tuple using tuple function
t=tuple("HELLO")
print(t)
l=[1,2,3,4,5]
t=tuple(l)
print(t)
# Out:
# ('H', 'E', 'L', 'L', 'O')
# (1, 2, 3, 4, 5)

# %%
print(tuple(s))
#conver dic to tuple
d={1:"a",2:"b",3:"c"}
print(tuple(d))  #by default key
print(tuple(d.values())) #here value take not keys
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-34169580.py in <cell line: 0>()
# ----> 1 print(tuple(s))
#       2 #conver dic to tuple
#       3 d={1:"a",2:"b",3:"c"}
#       4 print(tuple(d))  #by default key
#       5 print(tuple(d.values())) #here value take not keys
#
# NameError: name 's' is not defined

# %%
#tuple function
t=(11,22,33,44,44,55,44)
print(len(t))  #4
print(max(t))  #55
print(min(t))  #11
print(t.index(44))
print(t.count(44))
print(sum(t))
print(sorted(t))
print(sorted(t,reverse=True))
# Out:
# 7
# 55
# 11
# 3
# 3
# 253
# [11, 22, 33, 44, 44, 44, 55]
# [55, 44, 44, 44, 33, 22, 11]

# %%
#1
text = "Python"
print(text[0])  # Output: P (First character)
print(text[3])  # Output: h (Fourth character)
print(text[-1]) # Output: n (Last character)
# Out:
# P
# h
# n

# %%
#2
text = "Python is an amazing language"

print(f"Original String: {text}")
print(f"First character: {text[0]}")
print(f"Last character: {text[-1]}")
print(f"Extracted slice (0-6): {text[0:6]}")
# Out:
# Original String: Python is an amazing language
# First character: P
# Last character: e
# Extracted slice (0-6): Python

# %%
#3
print("\nWords and their lengths:")
words = text.split()
for word in words:
    print(f"{word}: {len(word)}")
# Out:
# Words and their lengths:
# Python: 6
# is: 2
# an: 2
# amazing: 7
# language: 8

# %%
#4
print("\nEven length words:")
even_words = [word for word in words if len(word) % 2 == 0]
print(even_words)
# Out:
# Even length words:
# ['Python', 'is', 'an', 'language']

# %%
#5
vowels = "aeiouAEIOU"
count = sum(1 for char in text if char in vowels)
print(f"\nTotal number of vowels: {count}")
# Out:
# Total number of vowels: 10

# %%
#6
def greet(name):
    print("Hello " + name)

greet("Alice")
# Out:
# Hello Alice

# %%
#7
text = "Hi! "
result = text * 3
print(result)
# Out:
# Hi! Hi! Hi!

# %%
#8
message = "Hello"
message += " World"
print(message)
# Out:
# Hello World

# %%
#9
str1 = "Good"
str2 = "Morning"
str3 = str1 + " " + str2
print(str3)
# Out:
# Good Morning

# %%
#10
sentence = "Python programming is fun"

if "programming" in sentence:
    print("Substring found")
else:
    print("Substring not found")
# Out:
# Substring found
